# %% [markdown]
# ## Liberiras

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# ## Importando el dataset

# %%
df = pd.read_csv(r'./data/clientes.csv', index_col= ['fecha'])
#df = df.sort_values(by=['fecha'])

df
# Out:
#          fecha    cedula     nombre  apellido  edad  \
# 0   04/13/2022  78252542     Andrea    Tirado    27
# 1   02/13/2022  27296468     Nissim     Kirby    43
# 2   04/20/2022  25692334  Francesca     Recio    22
# 3   04/26/2022  76558784      Sonya   Hickman    20
# 4   03/18/2022  63495229     Emilia   Escobar    32
# 5   03/18/2022  98836723     Malika     Badia    41
# 6   03/23/2022  36449937    Maitane     Reyes    51
# 7   02/24/2022  53755957  Esmeralda   Manzano    19
# 8   02/22/2022  57386234     Emilia    Roldan    23
# 9    02/2/2022  44342594     Victor   Pizarro    35
# 10  01/22/2022  24474744    Maialen     Simon    54
# 11  02/26/2022  62435852     Amanda      Lara    26
# 12  04/21/2022  25589838       Olga   Palacio    48
# 13  02/28/2022  75579322        Eva  Bermudez    20
# 14  03/22/2022  55934625      Lidia   Postigo    35
# 15  01/29/2022  65398434       Alex      Baez    41
# 16  03/19/2022  83272773      Edgar    Gascon    46
# 17  02/21/2022  79389655    Maribel    Olmedo    53
# 18  02/21/2022  36432423       Abel    Grande    23
#
#                          correo tipo de vehiculo            Marca  anno  \
# 0       Andrea.Tirado@gmail.com      Motocicleta           Yamaha  2000
# 1        Nissim.Kirby@gmail.com        Automovil             Audi  1994
# 2     Francesca.Recio@gmail.com        Automovil    Mercedes Benz  1963
# 3       Sonya.Hickman@gmail.com      Motocicleta              BMW  2013
# 4      Emilia.Escobar@gmail.com      Motocicleta  Harley davidson  2005
# 5        Malika.Badia@gmail.com        Automovil          Hyundai  2003
# 6       Maitane.Reyes@gmail.com      Motocicleta          Freedom  2003
# 7   Esmeralda.Manzano@gmail.com           Camion       Mitsubishi  2017
# 8       Emilia.Roldan@gmail.com        Automovil             Audi  2010
# 9      Victor.Pizarro@gmail.com      Motocicleta           Yamaha  2016
# 10      Maialen.Simon@gmail.com      Motocicleta           Yamaha  2016
# 11        Amanda.Lara@gmail.com        Automovil          Hyundai  2010
# 12       Olga.Palacio@gmail.com      Motocicleta           Yamaha  2003
# 13       Eva.Bermudez@gmail.com        Automovil       Volkswagen  2016
# 14      Lidia.Postigo@gmail.com      Motocicleta          Freedom  2006
# 15          Alex.Baez@gmail.com        Automovil           Toyota  1954
# 16       Edgar.Gascon@gmail.com        Automovil    Mercedes Benz  1996
# 17     Maribel.Olmedo@gmail.com        Automovil    Mercedes Benz  2016
# 18        Abel.Grande@gmail.com      Motocicleta          Freedom  2010
#
#     Coste del servicio  Cantidad cobrada al cliente  Remuneracion total
# 0                72980                      87576.0               14596
# 1                70520                      84624.0               14104
# 2               198352                     238022.0               39670
# 3               116084                     139301.0               23217
# 4                99477                     119372.0               19895
# 5                96564                     115877.0               19313
# 6                87714                     105257.0               17543
# 7                84211                     101053.0               16842
# 8                80258                      96310.0               16052
# 9                80006                      96007.0               16001
# 10               61500                      73800.0               12300
# 11               55419                      66503.0               11084
# 12               54910                      65892.0               10982
# 13               54791                      65749.0               10958
# 14               54354                      65225.0               10871
# 15               46567                      55880.0                9313
# 16               35678                      42814.0                7136
# 17               34811                      41773.0                6962
# 18               32905                      39486.0                6581

# %% [markdown]
# ## Ingreso de nuevos clientes

# %%
print("Ingrese la fecha de la consulta")
fecha = str(input())
print("ingrese la cedula del cliente (Solo ingresar los numeros)")
cedula = int(input())
print("Ingrese el nombre del cliente")
nombre = str(input())
print("Ingrese el apellido del cliente")
apellido = str(input())
print("Ingrese la edad del cliente")
edad = int(input())
print("Ingrese el correo del cliente")
correo = str(input())
print("Ingrese el tipo de vehiculo")
vehiculo = str(input())
print("Ingrese la marca del vehiculo")
marca = str(input())
print("ingrese el año del vehiculo")
anno = int(input())
print("Ingrese el coste para la empresa de la consulta")
coste_empresa = int(input())
print("Ingrese el valor cobrado al cliente")
coste_cliente = int(input())

remuneracion = coste_cliente-coste_empresa

df = df.append({'fecha':fecha, 'cedula':cedula, 'nombre':nombre, 'apellido': apellido,
                'edad':edad, 'correo':correo, 'tipo de vehiculo': vehiculo,'Marca':marca,
                'anno':anno, 'Coste del servicio':coste_empresa, 'Cantidad cobrada al cliente':coste_cliente,
                'Remuneracion total':remuneracion}, ignore_index=True)

df.to_csv('proyecto final\data\clientes.csv', index=False)
df.to_excel('proyecto final\data\clientes.xlsx')
print('------------------------------------------------')
print('Cliente agregado a la base de datos!')
print('------------------------------------------------')
df
# Out:
# Ingrese la fecha de la consulta
# ingrese la cedula del cliente (Solo ingresar los numeros)
# Ingrese el nombre del cliente
# Ingrese el apellido del cliente
# Ingrese la edad del cliente
# Ingrese el correo del cliente
# Ingrese el tipo de vehiculo
# Ingrese la marca del vehiculo
# ingrese el año del vehiculo
# Ingrese el coste para la empresa de la consulta
# Ingrese el valor cobrado al cliente
# ------------------------------------------------
# Cliente agregado a la base de datos!
# ------------------------------------------------
#          fecha     cedula     nombre  apellido  edad  \
# 0   04/13/2022   78252542     Andrea    Tirado    27
# 1   02/13/2022   27296468     Nissim     Kirby    43
# 2   04/20/2022   25692334  Francesca     Recio    22
# 3   04/26/2022   76558784      Sonya   Hickman    20
# 4   03/18/2022   63495229     Emilia   Escobar    32
# 5   03/18/2022   98836723     Malika     Badia    41
# 6   03/23/2022   36449937    Maitane     Reyes    51
# 7   02/24/2022   53755957  Esmeralda   Manzano    19
# 8   02/22/2022   57386234     Emilia    Roldan    23
# 9    02/2/2022   44342594     Victor   Pizarro    35
# 10  01/22/2022   24474744    Maialen     Simon    54
# 11  02/26/2022   62435852     Amanda      Lara    26
# 12  04/21/2022   25589838       Olga   Palacio    48
# 13  02/28/2022   75579322        Eva  Bermudez    20
# 14  03/22/2022   55934625      Lidia   Postigo    35
# 15  01/29/2022   65398434       Alex      Baez    41
# 16  03/19/2022   83272773      Edgar    Gascon    46
# 17  02/21/2022   79389655    Maribel    Olmedo    53
# 18  02/21/2022   36432423       Abel    Grande    23
# 19  05/21/2022  118220515       Gabo      leon    20
# 20  06/18/2022   11111111      emily   Berrios    19
#
#                          correo tipo de vehiculo            Marca  anno  \
# 0       Andrea.Tirado@gmail.com      Motocicleta           Yamaha  2000
# 1        Nissim.Kirby@gmail.com        Automovil             Audi  1994
# 2     Francesca.Recio@gmail.com        Automovil    Mercedes Benz  1963
# 3       Sonya.Hickman@gmail.com      Motocicleta              BMW  2013
# 4      Emilia.Escobar@gmail.com      Motocicleta  Harley davidson  2005
# 5        Malika.Badia@gmail.com        Automovil          Hyundai  2003
# 6       Maitane.Reyes@gmail.com      Motocicleta          Freedom  2003
# 7   Esmeralda.Manzano@gmail.com           Camion       Mitsubishi  2017
# 8       Emilia.Roldan@gmail.com        Automovil             Audi  2010
# 9      Victor.Pizarro@gmail.com      Motocicleta           Yamaha  2016
# 10      Maialen.Simon@gmail.com      Motocicleta           Yamaha  2016
# 11        Amanda.Lara@gmail.com        Automovil          Hyundai  2010
# 12       Olga.Palacio@gmail.com      Motocicleta           Yamaha  2003
# 13       Eva.Bermudez@gmail.com        Automovil       Volkswagen  2016
# 14      Lidia.Postigo@gmail.com      Motocicleta          Freedom  2006
# 15          Alex.Baez@gmail.com        Automovil           Toyota  1954
# 16       Edgar.Gascon@gmail.com        Automovil    Mercedes Benz  1996
# 17     Maribel.Olmedo@gmail.com        Automovil    Mercedes Benz  2016
# 18        Abel.Grande@gmail.com      Motocicleta          Freedom  2010
# 19                         test          Hyundai          Hiunday  2016
# 20                         test          Hyundai          Hyundai  2017
#
#     Coste del servicio  Cantidad cobrada al cliente  Remuneracion total
# 0                72980                      87576.0               14596
# 1                70520                      84624.0               14104
# 2               198352                     238022.0               39670
# 3               116084                     139301.0               23217
# 4                99477                     119372.0               19895
# 5                96564                     115877.0               19313
# 6                87714                     105257.0               17543
# 7                84211                     101053.0               16842
# 8                80258                      96310.0               16052
# 9                80006                      96007.0               16001
# 10               61500                      73800.0               12300
# 11               55419                      66503.0               11084
# 12               54910                      65892.0               10982
# 13               54791                      65749.0               10958
# 14               54354                      65225.0               10871
# 15               46567                      55880.0                9313
# 16               35678                      42814.0                7136
# 17               34811                      41773.0                6962
# 18               32905                      39486.0                6581
# 19               20000                      30000.0               10000
# 20               40000                      50000.0               10000

# %% [markdown]
# ## Reporte

# %% [markdown]
# ### Descripcion estadistica basica del dataframe

# %%
analisis_estadistico = round(df[['edad', 'anno', 'Coste del servicio', 'Cantidad cobrada al cliente', 'Remuneracion total']].describe(), 2)
#analisis_estadistico['Metrica'] = ['Conteo de filas', 'Promedio', 'Desviacion Estandar', 'Min', '25%', '50%/Media', '75%', 'Max']
analisis_estadistico.insert(0, 'Metricas', ['Conteo de filas', 'Promedio', 'Desviacion Estandar', 'Min', '25%', '50%/Media', '75%', 'Max'])
analisis_estadistico
# Out:
#                   Metricas   edad     anno  Coste del servicio  \
# count      Conteo de filas  21.00    21.00               21.00
# mean              Promedio  33.24  2004.00            70338.14
# std    Desviacion Estandar  12.45    16.76            38490.54
# min                    Min  19.00  1954.00            20000.00
# 25%                    25%  22.00  2003.00            46567.00
# 50%              50%/Media  32.00  2010.00            61500.00
# 75%                    75%  43.00  2016.00            84211.00
# max                    Max  54.00  2017.00           198352.00
#
#        Cantidad cobrada al cliente  Remuneracion total
# count                        21.00               21.00
# mean                      84786.71            14448.57
# std                       45735.20             7338.49
# min                       30000.00             6581.00
# 25%                       55880.00            10000.00
# 50%                       73800.00            12300.00
# 75%                      101053.00            16842.00
# max                      238022.00            39670.00

# %%
df = pd.read_csv(r'./data/clientes.csv', parse_dates=['fecha'],
                                         index_col= ['fecha'])
df = df.sort_values(by=['fecha'])
# Create figure and plot space
fig, ax = plt.subplots(figsize=(12, 12))

# Add x-axis and y-axis
ax.bar(df.index.values,
       df['Remuneracion total'],
       color='purple')

# Set title and labels for axes
ax.set(xlabel="Fecha",
       ylabel="Remuneración para el taller",
       title="Remuneracion de la empresa a lo largo del tiempo")

plt.savefig("./output/Remuneracion_de_la_empresa_a_lo_largo_del_tiempo.pdf", format="pdf", bbox_inches="tight")
plt.show()
