# %% [markdown]
# ## Liberiras

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# ## Importando el dataset

# %%
df = pd.read_csv(r'./data/clientes.csv', parse_dates=['fecha'],
                 						 index_col= ['fecha'])
df = df.sort_values(by=['fecha'])

df
# Out:
#               cedula     nombre  apellido  edad                       correo  \
# fecha
# 2022-01-22  24474744    Maialen     Simon    54      Maialen.Simon@gmail.com
# 2022-01-29  65398434       Alex      Baez    41          Alex.Baez@gmail.com
# 2022-02-02  44342594     Victor   Pizarro    35     Victor.Pizarro@gmail.com
# 2022-02-13  27296468     Nissim     Kirby    43       Nissim.Kirby@gmail.com
# 2022-02-21  79389655    Maribel    Olmedo    53     Maribel.Olmedo@gmail.com
# 2022-02-21  36432423       Abel    Grande    23        Abel.Grande@gmail.com
# 2022-02-22  57386234     Emilia    Roldan    23      Emilia.Roldan@gmail.com
# 2022-02-24  53755957  Esmeralda   Manzano    19  Esmeralda.Manzano@gmail.com
# 2022-02-26  62435852     Amanda      Lara    26        Amanda.Lara@gmail.com
# 2022-02-28  75579322        Eva  Bermudez    20       Eva.Bermudez@gmail.com
# 2022-03-18  63495229     Emilia   Escobar    32     Emilia.Escobar@gmail.com
# 2022-03-18  98836723     Malika     Badia    41       Malika.Badia@gmail.com
# 2022-03-19  83272773      Edgar    Gascon    46       Edgar.Gascon@gmail.com
# 2022-03-22  55934625      Lidia   Postigo    35      Lidia.Postigo@gmail.com
# 2022-03-23  36449937    Maitane     Reyes    51      Maitane.Reyes@gmail.com
# 2022-04-13  78252542     Andrea    Tirado    27      Andrea.Tirado@gmail.com
# 2022-04-20  25692334  Francesca     Recio    22    Francesca.Recio@gmail.com
# 2022-04-21  25589838       Olga   Palacio    48       Olga.Palacio@gmail.com
# 2022-04-26  76558784      Sonya   Hickman    20      Sonya.Hickman@gmail.com
#
#            tipo de vehiculo            Marca  anno  Coste del servicio  \
# fecha
# 2022-01-22      Motocicleta           Yamaha  2016               61500
# 2022-01-29        Automovil           Toyota  1954               46567
# 2022-02-02      Motocicleta           Yamaha  2016               80006
# 2022-02-13        Automovil             Audi  1994               70520
# 2022-02-21        Automovil    Mercedes Benz  2016               34811
# 2022-02-21      Motocicleta          Freedom  2010               32905
# 2022-02-22        Automovil             Audi  2010               80258
# 2022-02-24           Camion       Mitsubishi  2017               84211
# 2022-02-26        Automovil          Hyundai  2010               55419
# 2022-02-28        Automovil       Volkswagen  2016               54791
# 2022-03-18      Motocicleta  Harley davidson  2005               99477
# 2022-03-18        Automovil          Hyundai  2003               96564
# 2022-03-19        Automovil    Mercedes Benz  1996               35678
# 2022-03-22      Motocicleta          Freedom  2006               54354
# 2022-03-23      Motocicleta          Freedom  2003               87714
# 2022-04-13      Motocicleta           Yamaha  2000               72980
# 2022-04-20        Automovil    Mercedes Benz  1963              198352
# 2022-04-21      Motocicleta           Yamaha  2003               54910
# 2022-04-26      Motocicleta              BMW  2013              116084
#
#             Cantidad cobrada al cliente  Remuneracion total
# fecha
# 2022-01-22                        73800               12300
# 2022-01-29                        55880                9313
# 2022-02-02                        96007               16001
# 2022-02-13                        84624               14104
# 2022-02-21                        41773                6962
# 2022-02-21                        39486                6581
# 2022-02-22                        96310               16052
# 2022-02-24                       101053               16842
# 2022-02-26                        66503               11084
# 2022-02-28                        65749               10958
# 2022-03-18                       119372               19895
# 2022-03-18                       115877               19313
# 2022-03-19                        42814                7136
# 2022-03-22                        65225               10871
# 2022-03-23                       105257               17543
# 2022-04-13                        87576               14596
# 2022-04-20                       238022               39670
# 2022-04-21                        65892               10982
# 2022-04-26                       139301               23217

# %% [markdown]
# ## Ingreso de nuevos clientes

# %%
print("Ingrese la fecha de la consulta")
fecha = str(input())
print("ingrese la cedula del cliente (Solo ingresar los numeros)")
cedula = int(input())
print("Ingrese el nombre del cliente")
nombre = str(input())
print("Ingrese el apellido del cliente")
apellido = str(input())
print("Ingrese la edad del cliente")
edad = int(input())
print("Ingrese el correo del cliente")
correo = str(input())
print("Ingrese el tipo de vehiculo")
vehiculo = str(input())
print("Ingrese la marca del vehiculo")
marca = str(input())
print("ingrese el año del vehiculo")
anno = int(input())
print("Ingrese el coste para la empresa de la consulta")
coste_empresa = int(input())
print("Ingrese el valor cobrado al cliente")
coste_cliente = int(input())

remuneracion = coste_cliente-coste_empresa

df = df.append({'fecha':fecha, 'cedula':cedula, 'nombre':nombre, 'apellido': apellido,
                'edad':edad, 'correo':correo, 'tipo de vehiculo': vehiculo,'Marca':marca,
                'anno':anno, 'Coste del servicio':coste_empresa, 'cantidad cobrada al cliente':coste_cliente,
                'Remuneracion total':remuneracion}, ignore_index=True)

df
# Out:
# Ingrese la fecha de la consulta
# ingrese la cedula del cliente (Solo ingresar los numeros)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7184/2184174399.py in <module>
#       2 fecha = str(input())
#       3 print("ingrese la cedula del cliente (Solo ingresar los numeros)")
# ----> 4 cedula = int(input())
#       5 print("Ingrese el nombre del cliente")
#       6 nombre = str(input())
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ## Reporte

# %% [markdown]
# ### Descripcion estadistica basica del dataframe

# %%
analisis_estadistico = round(df[['edad', 'anno', 'Coste del servicio', 'Cantidad cobrada al cliente', 'Remuneracion total']].describe(), 2)

# %% [markdown]
# ### Creacion del grafico

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(12, 12))

# Add x-axis and y-axis
ax.bar(df.index.values,
       df['Remuneracion total'],
       color='purple')

# Set title and labels for axes
ax.set(xlabel="Fecha",
       ylabel="Remuneración para el taller",
       title="Remuneracion de la empresa a lo largo del tiempo")

plt.savefig("./output/Remuneracion_de_la_empresa_a_lo_largo_del_tiempo.pdf", format="pdf", bbox_inches="tight")
plt.show()
